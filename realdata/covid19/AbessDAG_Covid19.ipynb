# %%
import os
import pandas as pd
import numpy as np
import abess
import joblib
import networkx as nx
import math

# %%
df = pd.read_csv('time_series_covid19_confirmed_global.csv')
new_df = df.groupby('Country/Region').sum()
df = new_df.transpose()
df = df.drop(index=['Lat','Long'])
df = df.diff()
df = df.drop(index=['1/22/20'])

# %%
def iscompatible(kset):
    kset_tuple = kset.apply(tuple,axis=1).tolist()
    G=nx.DiGraph()
    G.add_edges_from(kset_tuple)
    result = nx.is_directed_acyclic_graph(G)
    return result

def mostcauses(kset):
    ksetv = kset.Cause.value_counts()
    mostc = ksetv[ksetv==ksetv.max()].index
    return mostc

def pps(i,kset,edges):
    edges = pd.DataFrame(edges, columns=["From", "To"])
    kset_subset = kset.loc[kset['Cause']==i]
    props1 = set(kset_subset.Effect)
    props = props1
    edges_tuple = edges.apply(tuple,axis=1).tolist()
    G=nx.DiGraph()
    G.add_edges_from(edges_tuple)
    for j in props1:
        if G.has_node(j):
            props = props.union(nx.descendants(G,j)) 
    return props

def batchimport(kset,causes,effects):
    for i in causes:
        for j in effects:
            kset.loc[len(kset)] = [i,j]
    return kset

# %%
def fit_model(args):
    model, X, y = args
    model.fit(X, y)
    return model

def abessdag_fast (data_in, nu=0, kset=pd.DataFrame(columns=["Cause", "Effect"])
                   , wkset=pd.DataFrame(columns=["Cause", "Effect"]), strategy="DB"):
    data = data_in.copy()
    if (kset.empty) and (wkset.empty):
        if (nu==0):
            data = data_in.copy()
            order = []
            ancestors = data[[data.std().idxmin()]]
            order.append(data.std().idxmin())
            data = data.drop(data.std().idxmin(), axis=1)
            edges = []
            p = data.shape[1]
            for _ in range(p):
                stdlist = []
                ancestors_values = ancestors.values
                for i in data.columns:
                    model = abess.LinearRegression()
                    model.fit(ancestors_values, data[i])
                    ind = np.nonzero(model.coef_)[0]
                    if ancestors.shape[1]==1:
                        res = data[i] - model.predict(ancestors.values)[:,1]
                    else:
                        res = data[i] - model.predict(ancestors_values)   
                    stdlist.append((i, res.std(), ind))
                mini, _, minind = min(stdlist, key=lambda x: x[1])
                order.append(mini)
                for j in minind:
                    edges.append((ancestors.columns[j], mini))
                ancestors = pd.concat((ancestors, data[mini]), axis=1)
                data = data.drop(mini, axis=1)
            edges = pd.DataFrame(edges, columns=["From", "To"])
            return order, edges
        if (nu<0):
            raise ValueError("The threshold can't be negative.")
        if (nu>0):
            n = data.shape[0]
            order = []
            w=(data**2).sum()
            choose_ind = w[w<=w.min()+nu*n].index
            ancestors = data[choose_ind]
            data = data.drop(choose_ind,axis=1)
            order.append(choose_ind.tolist())
            edges = []
    
            if (len(choose_ind)==1):
                stdlist = pd.DataFrame(data=None,columns=['Vertex','loss','ind'])
                models = []
                for i in data.columns:
                    model = abess.LinearRegression()
                    models.append(model)
                results = joblib.Parallel(n_jobs=-1)(
                    joblib.delayed(fit_model)(args)
                    for args in zip(models, [ancestors.values]*len(models), [data[i] for i in data.columns])
                )
                for i, result in enumerate(results):
                    ind = np.nonzero(result.coef_)
                    res = data[data.columns[i]] - result.predict(ancestors.values)[:,1]
                    stdlist.loc[len(stdlist)] = [data.columns[i], (res**2).sum(), ind]
                w = stdlist["loss"]
                choose_ind = w[w<=w.min()+nu*n].index
                vertex_ind = stdlist["Vertex"][choose_ind].tolist()
                order.append(vertex_ind)
                for k in vertex_ind:
                    minind = stdlist.loc[stdlist["Vertex"]==k,"ind"].item()[0]
                    for j in minind:
                        edges.append((ancestors.columns[j], k))
                    ancestors.insert(loc=0 ,column=k, value=data[k])
                    data = data.drop(k, axis=1)
      
            while (data.shape[1]>0):
                stdlist = pd.DataFrame(data=None,columns=['Vertex','loss','ind'])
                models = []
                for i in data.columns:
                    model = abess.LinearRegression()
                    models.append(model)
                results = joblib.Parallel(n_jobs=-1)(
                    joblib.delayed(fit_model)(args)
                    for args in zip(models, [ancestors.values]*len(models), [data[i] for i in data.columns])
                )
                for i, result in enumerate(results):
                    ind = np.nonzero(result.coef_)
                    res = data[data.columns[i]] - result.predict(ancestors.values)
                    stdlist.loc[len(stdlist)] = [data.columns[i], (res**2).sum(), ind]
                w = stdlist["loss"]
                choose_ind = w[w<=w.min()+nu*n].index
                vertex_ind = stdlist["Vertex"][choose_ind].tolist()
                order.append(vertex_ind)
                for k in vertex_ind:
                    minind = stdlist.loc[stdlist["Vertex"]==k,"ind"].item()[0]
                    for j in minind:
                        edges.append((ancestors.columns[j], k))
                    ancestors = pd.concat((ancestors,data[k]),axis=1)
                    data = data.drop(k, axis=1)
            edges = pd.DataFrame(edges, columns=["From", "To"])
            return order, edges
    
    else:
        order = []
        for col in ['Cause', 'Effect']:
            if not set(getattr(kset, col)).issubset(set(data.columns)) or not set(getattr(wkset, col)).issubset(set(data.columns)):
                raise ValueError("Knowledge set should contain the names of variables.")
        if (not iscompatible(kset)) and (not (kset.empty)):
            raise ValueError("Strong knowledge set must be compatible.")
        if (strategy == "KB") and (kset.empty):
            data_frac = data[mostcauses(wkset)]
            ancestors = data_frac[[data_frac.std().idxmin()]]
            order.append(data_frac.std().idxmin())
            wkset = wkset.drop(wkset[wkset['Cause'] == data_frac.std().idxmin()].index)
            data = data.drop(data_frac.std().idxmin(), axis=1)
            edges = []
            p = data.shape[1]
            for _ in range(p):
                stdlist = []
                desc = data.columns if (wkset.empty) else mostcauses(wkset)
                for i in desc:
                    props = pps(i,wkset,edges)
                    props = props.intersection(ancestors.columns)  # Prohibited parent set
                    model = abess.LinearRegression()
                    anc = ancestors.drop(columns=props)
                    if anc.empty:
                        stdlist.append((i, data[i].std(), np.empty((0,), dtype=np.int64)))
                    if anc.shape[1]==1:
                        model.fit(anc.values,data[i])  # Use some of the ancestors to do variable selection
                        ind = np.nonzero(model.coef_)[0]
                        res = data[i] - model.predict(anc.values)[:,1]
                    if anc.shape[1]>=2:
                        model.fit(anc.values,data[i])  # Use some of the ancestors to do variable selection
                        ind = np.nonzero(model.coef_)[0]
                        res = data[i] - model.predict(anc.values)
                    stdlist.append((i, res.std(), ind))
                mini, _, minind = min(stdlist, key=lambda x: x[1])
                order.append(mini)
                props = pps(mini,wkset,edges)
                props = props.intersection(ancestors.columns)
                anc = ancestors.drop(columns=props)
                for j in minind:
                    edges.append((anc.columns[j],mini))
                ancestors = pd.concat((ancestors,data[mini]),axis=1)
                data = data.drop(mini, axis=1)
                wkset = wkset.drop(wkset[wkset['Cause'] == mini].index)
            return order, edges
        else:    
            data_frac = data[data.columns.drop(set(kset.Effect))]
            ancestors = data_frac[[data_frac.std().idxmin()]]
            order.append(data_frac.std().idxmin())
            kset = kset.drop(kset[kset['Cause'] == data_frac.std().idxmin()].index)
            data = data.drop(data_frac.std().idxmin(), axis=1)
            edges = []
            p = data.shape[1]
            for _ in range(p):
                stdlist = []
                cols_to_drop = set(kset.Effect) & set(data.columns)
                for i in data.columns.drop(cols_to_drop):
                    props = pps(i,wkset,edges)
                    props = props.intersection(ancestors.columns)  # Prohibited parent set
                    model = abess.LinearRegression()
                    anc = ancestors.drop(columns=props)
                    if anc.empty:
                        stdlist.append((i, data[i].std(), np.empty((0,), dtype=np.int64)))
                    if anc.shape[1]==1:
                        model.fit(anc.values,data[i])  # Use some of the ancestors to do variable selection
                        ind = np.nonzero(model.coef_)[0]
                        res = data[i] - model.predict(anc.values)[:,1]
                    if anc.shape[1]>=2:
                        model.fit(anc.values,data[i])  # Use some of the ancestors to do variable selection
                        ind = np.nonzero(model.coef_)[0]
                        res = data[i] - model.predict(anc.values)
                    stdlist.append((i, res.std(), ind))
                mini, _, minind = min(stdlist, key=lambda x: x[1])
                order.append(mini)
                props = pps(mini,wkset,edges)
                props = props.intersection(ancestors.columns)
                anc = ancestors.drop(columns=props)
                for j in minind:
                    edges.append((anc.columns[j],mini))
                ancestors = pd.concat((ancestors,data[mini]),axis=1)
                data = data.drop(mini, axis=1)
                kset = kset.drop(kset[kset['Cause'] == mini].index)
                
            return order, edges

# %%
zeros_count = df.eq(0).sum()
for col, count in zeros_count.items():
    if count > 570:
        print(f"Column '{col}' has {count} zeros.")
# Out:
# Column 'Andorra' has 623 zeros.
# Column 'Antarctica' has 1141 zeros.
# Column 'Antigua and Barbuda' has 805 zeros.
# Column 'Benin' has 962 zeros.
# Column 'Bhutan' has 620 zeros.
# Column 'Botswana' has 905 zeros.
# Column 'Brunei' has 697 zeros.
# Column 'Burkina Faso' has 608 zeros.
# Column 'Burundi' has 629 zeros.
# Column 'Cameroon' has 937 zeros.
# Column 'Central African Republic' has 905 zeros.
# Column 'Chad' has 630 zeros.
# Column 'Comoros' has 692 zeros.
# Column 'Congo (Brazzaville)' has 966 zeros.
# Column 'Diamond Princess' has 1127 zeros.
# Column 'Dominica' has 940 zeros.
# Column 'El Salvador' has 657 zeros.
# Column 'Equatorial Guinea' has 834 zeros.
# Column 'Eritrea' has 633 zeros.
# Column 'Fiji' has 790 zeros.
# Column 'Gabon' has 776 zeros.
# Column 'Gambia' has 818 zeros.
# Column 'Ghana' has 591 zeros.
# Column 'Grenada' has 875 zeros.
# Column 'Guinea' has 600 zeros.
# Column 'Guinea-Bissau' has 737 zeros.
# Column 'Holy See' has 1129 zeros.
# Column 'Kiribati' has 1052 zeros.
# Column 'Korea, North' has 1141 zeros.
# Column 'Lesotho' has 837 zeros.
# Column 'Liberia' has 776 zeros.
# Column 'MS Zaandam' has 1140 zeros.
# Column 'Madagascar' has 699 zeros.
# Column 'Marshall Islands' has 1084 zeros.
# Column 'Mauritius' has 745 zeros.
# Column 'Micronesia' has 1082 zeros.
# Column 'Nauru' has 1109 zeros.
# Column 'Nicaragua' has 986 zeros.
# Column 'Palau' has 1025 zeros.
# Column 'Papua New Guinea' has 706 zeros.
# Column 'Saint Kitts and Nevis' has 761 zeros.
# Column 'Saint Lucia' has 594 zeros.
# Column 'Saint Vincent and the Grenadines' has 728 zeros.
# Column 'Samoa' has 1043 zeros.
# Column 'San Marino' has 593 zeros.
# Column 'Sao Tome and Principe' has 674 zeros.
# Column 'Seychelles' has 733 zeros.
# Column 'Sierra Leone' has 587 zeros.
# Column 'Solomon Islands' has 1067 zeros.
# Column 'Somalia' has 813 zeros.
# Column 'South Sudan' has 669 zeros.
# Column 'Sudan' has 649 zeros.
# Column 'Summer Olympics 2020' has 1103 zeros.
# Column 'Sweden' has 598 zeros.
# Column 'Tajikistan' has 783 zeros.
# Column 'Tanzania' has 1050 zeros.
# Column 'Timor-Leste' has 618 zeros.
# Column 'Tonga' has 1042 zeros.
# Column 'Tuvalu' has 1128 zeros.
# Column 'Vanuatu' has 990 zeros.
# Column 'Winter Olympics 2022' has 1108 zeros.

# %%
columns_to_drop = zeros_count[zeros_count > 570].index.tolist()
# 从 DataFrame 中删除符合条件的列
df = df.drop(columns_to_drop, axis=1)

# %%
window_size = 3
df = df.rolling(window_size).mean()
df = df.drop(index=['1/23/20','1/24/20'])

# %%
pop = pd.read_csv('population.csv')
pop = pop.set_index('Country Name').transpose()
pop = pop.squeeze()
sqpop =  pop.apply(np.sqrt)
dfbysqpop = df.div(sqpop, axis=1)

# %%
dfbysqpop
# Out:
# Country/Region  Afghanistan   Albania   Algeria    Angola  Argentina  \
# 1/25/20            0.000000  0.000000  0.000000  0.000000   0.000000
# 1/26/20            0.000000  0.000000  0.000000  0.000000   0.000000
# 1/27/20            0.000000  0.000000  0.000000  0.000000   0.000000
# 1/28/20            0.000000  0.000000  0.000000  0.000000   0.000000
# 1/29/20            0.000000  0.000000  0.000000  0.000000   0.000000
# ...                     ...       ...       ...       ...        ...
# 3/5/23             0.001684  0.003777  0.000702  0.000000   0.000000
# 3/6/23             0.002316  0.000000  0.000401  0.000000   0.040976
# 3/7/23             0.003527  0.000000  0.001053  0.000000   0.040976
# 3/8/23             0.003211  0.003181  0.000853  0.000624   0.040976
# 3/9/23             0.002369  0.005964  0.000953  0.000624   0.000000
#
# Country/Region   Armenia  Australia   Austria  Azerbaijan  Bahamas  ...  \
# 1/25/20         0.000000   0.000000  0.000000    0.000000      0.0  ...
# 1/26/20         0.000000   0.000263  0.000000    0.000000      0.0  ...
# 1/27/20         0.000000   0.000329  0.000000    0.000000      0.0  ...
# 1/28/20         0.000000   0.000329  0.000000    0.000000      0.0  ...
# 1/29/20         0.000000   0.000132  0.000000    0.000000      0.0  ...
# ...                  ...        ...       ...         ...      ...  ...
# 3/5/23          0.000000   0.041631  1.647050    0.009736      0.0  ...
# 3/6/23          0.000000   0.000000  1.355555    0.008585      0.0  ...
# 3/7/23          0.000000   0.000000  1.420381    0.010574      0.0  ...
# 3/8/23          0.097569   0.000000  1.662421    0.010260      0.0  ...
# 3/9/23          0.097569   0.915882  1.974410    0.009946      0.0  ...
#
# Country/Region  United Arab Emirates  United Kingdom  Uruguay  Uzbekistan  \
# 1/25/20                     0.000000        0.000000      0.0    0.000000
# 1/26/20                     0.000000        0.000000      0.0    0.000000
# 1/27/20                     0.000000        0.000000      0.0    0.000000
# 1/28/20                     0.000000        0.000000      0.0    0.000000
# 1/29/20                     0.000436        0.000000      0.0    0.000000
# ...                              ...             ...      ...         ...
# 3/5/23                      0.045421        0.000406      0.0    0.000000
# 3/6/23                      0.030716        0.000000      0.0    0.000000
# 3/7/23                      0.044332        0.000244      0.0    0.000000
# 3/8/23                      0.044005        0.003331      0.0    0.009929
# 3/9/23                      0.059799        1.172619      0.0    0.009929
#
# Country/Region  Venezuela   Vietnam  West Bank and Gaza  Yemen   Zambia  \
# 1/25/20          0.000000  0.000068                 0.0    0.0  0.00000
# 1/26/20          0.000000  0.000000                 0.0    0.0  0.00000
# 1/27/20          0.000000  0.000000                 0.0    0.0  0.00000
# 1/28/20          0.000000  0.000000                 0.0    0.0  0.00000
# 1/29/20          0.000000  0.000000                 0.0    0.0  0.00000
# ...                   ...       ...                 ...    ...      ...
# 3/5/23           0.004080  0.000979                 0.0    0.0  0.00423
# 3/6/23           0.006968  0.000540                 0.0    0.0  0.00423
# 3/7/23           0.006654  0.000810                 0.0    0.0  0.00423
# 3/8/23           0.006654  0.000945                 0.0    0.0  0.00000
# 3/9/23           0.002323  0.000945                 0.0    0.0  0.00000
#
# Country/Region  Zimbabwe
# 1/25/20         0.000000
# 1/26/20         0.000000
# 1/27/20         0.000000
# 1/28/20         0.000000
# 1/29/20         0.000000
# ...                  ...
# 3/5/23          0.000000
# 3/6/23          0.000000
# 3/7/23          0.000000
# 3/8/23          0.012419
# 3/9/23          0.012419
#
# [1140 rows x 140 columns]

# %%
def first_nonzero_index(column):
    nonzero_indices = column.to_numpy().nonzero()[0]
    return nonzero_indices[0] if len(nonzero_indices) > 0 else None

first_nonzero_indices = dfbysqpop.apply(first_nonzero_index)
result = pd.concat([pop,first_nonzero_indices], axis=1)
rowlist = list(set(result[0]))

# %%
kset = pd.DataFrame({"Cause":[],"Effect":[]})
for a, b in zip(rowlist, rowlist[1:]):
    kset = batchimport(kset,list(result.loc[result[0] == a].index),list(result.loc[result[0] == b].index))
second_day_nonzero = ['Canada', 'France', 'Korea, South', 'Malaysia', 'Nepal', 'Singapore', 'Taiwan*', 'Thailand', 'Vietnam']
chinaus=['China','US']
kset = batchimport(kset,chinaus,second_day_nonzero)

# %%
data = dfbysqpop.iloc[56:206, :]
DAGresult = abessdag_fast(data,kset=kset)

# %%
DAGresult[1]
# Out:
# [('China', 'US'),
#  ('US', 'Vietnam'),
#  ('China', 'Taiwan*'),
#  ('US', 'Taiwan*'),
#  ('China', 'Thailand'),
#  ('Vietnam', 'Thailand'),
#  ('Taiwan*', 'Thailand'),
#  ('US', 'Korea, South'),
#  ('Taiwan*', 'Korea, South'),
#  ('US', 'Malaysia'),
#  ('Thailand', 'Malaysia'),
#  ('Korea, South', 'Nepal'),
#  ('Malaysia', 'Nepal'),
#  ('China', 'Canada'),
#  ('US', 'Canada'),
#  ('Taiwan*', 'Canada'),
#  ('Malaysia', 'Canada'),
#  ('Nepal', 'Canada'),
#  ('US', 'Singapore'),
#  ('Vietnam', 'Singapore'),
#  ('Taiwan*', 'Singapore'),
#  ('Thailand', 'Singapore'),
#  ('Korea, South', 'Singapore'),
#  ('Malaysia', 'Singapore'),
#  ('Nepal', 'Singapore'),
#  ('Canada', 'Singapore'),
#  ('Malaysia', 'France'),
#  ('China', 'Australia'),
#  ('US', 'Australia'),
#  ('Vietnam', 'Australia'),
#  ('Taiwan*', 'Australia'),
#  ('Nepal', 'Australia'),
#  ('Canada', 'Australia'),
#  ('US', 'Japan'),
#  ('Vietnam', 'Japan'),
#  ('Canada', 'Japan'),
#  ('Taiwan*', 'Cambodia'),
#  ('Australia', 'Cambodia'),
#  ('Vietnam', 'Sri Lanka'),
#  ('Thailand', 'Germany'),
#  ('Canada', 'Germany'),
#  ('Singapore', 'Germany'),
#  ('Japan', 'Germany'),
#  ('Cambodia', 'Germany'),
#  ('China', 'Finland'),
#  ('Thailand', 'Finland'),
#  ('Canada', 'Finland'),
#  ('Japan', 'Finland'),
#  ('Vietnam', 'United Arab Emirates'),
#  ('Taiwan*', 'United Arab Emirates'),
#  ('Thailand', 'United Arab Emirates'),
#  ('Nepal', 'United Arab Emirates'),
#  ('France', 'United Arab Emirates'),
#  ('Australia', 'United Arab Emirates'),
#  ('Cambodia', 'United Arab Emirates'),
#  ('Finland', 'United Arab Emirates'),
#  ('Vietnam', 'Philippines'),
#  ('Thailand', 'Philippines'),
#  ('Korea, South', 'Philippines'),
#  ('Canada', 'Philippines'),
#  ('Japan', 'Philippines'),
#  ('US', 'India'),
#  ('Thailand', 'India'),
#  ('Korea, South', 'India'),
#  ('France', 'India'),
#  ('Japan', 'India'),
#  ('Cambodia', 'India'),
#  ('Finland', 'India'),
#  ('Philippines', 'India'),
#  ('Canada', 'United Kingdom'),
#  ('Cambodia', 'United Kingdom'),
#  ('Germany', 'United Kingdom'),
#  ('Finland', 'United Kingdom'),
#  ('China', 'Italy'),
#  ('US', 'Italy'),
#  ('Taiwan*', 'Italy'),
#  ('Nepal', 'Italy'),
#  ('France', 'Italy'),
#  ('Cambodia', 'Italy'),
#  ('Germany', 'Italy'),
#  ('Finland', 'Italy'),
#  ('US', 'Russia'),
#  ('Vietnam', 'Russia'),
#  ('Thailand', 'Russia'),
#  ('Nepal', 'Russia'),
#  ('Singapore', 'Russia'),
#  ('Japan', 'Russia'),
#  ('Italy', 'Russia'),
#  ('US', 'Spain'),
#  ('France', 'Spain'),
#  ('Australia', 'Spain'),
#  ('Germany', 'Spain'),
#  ('Philippines', 'Spain'),
#  ('Taiwan*', 'Belgium'),
#  ('Singapore', 'Belgium'),
#  ('France', 'Belgium'),
#  ('Japan', 'Belgium'),
#  ('Germany', 'Belgium'),
#  ('China', 'Egypt'),
#  ('US', 'Egypt'),
#  ('Vietnam', 'Egypt'),
#  ('Taiwan*', 'Egypt'),
#  ('Korea, South', 'Egypt'),
#  ('Nepal', 'Egypt'),
#  ('France', 'Egypt'),
#  ('Cambodia', 'Egypt'),
#  ('Finland', 'Egypt'),
#  ('United Arab Emirates', 'Egypt'),
#  ('Philippines', 'Egypt'),
#  ('India', 'Egypt'),
#  ('United Kingdom', 'Egypt'),
#  ('Italy', 'Egypt'),
#  ('Russia', 'Egypt'),
#  ('China', 'Iran'),
#  ('Korea, South', 'Iran'),
#  ('Malaysia', 'Iran'),
#  ('Nepal', 'Iran'),
#  ('Australia', 'Iran'),
#  ('Cambodia', 'Iran'),
#  ('United Arab Emirates', 'Iran'),
#  ('Spain', 'Iran'),
#  ('Egypt', 'Iran'),
#  ('US', 'Lebanon'),
#  ('Korea, South', 'Lebanon'),
#  ('Australia', 'Lebanon'),
#  ('Sri Lanka', 'Lebanon'),
#  ('Germany', 'Lebanon'),
#  ('India', 'Lebanon'),
#  ('Egypt', 'Lebanon'),
#  ('US', 'Israel'),
#  ('Nepal', 'Israel'),
#  ('United Kingdom', 'Israel'),
#  ('Spain', 'Israel'),
#  ('US', 'Chile'),
#  ('Vietnam', 'Chile'),
#  ('Nepal', 'Chile'),
#  ('United Arab Emirates', 'Chile'),
#  ('Egypt', 'Chile'),
#  ('Lebanon', 'Chile'),
#  ('US', 'Afghanistan'),
#  ('United Arab Emirates', 'Afghanistan'),
#  ('Iran', 'Afghanistan'),
#  ('Chile', 'Afghanistan'),
#  ('US', 'Iraq'),
#  ('Korea, South', 'Iraq'),
#  ('Malaysia', 'Iraq'),
#  ('Nepal', 'Iraq'),
#  ('Canada', 'Iraq'),
#  ('France', 'Iraq'),
#  ('Cambodia', 'Iraq'),
#  ('Sri Lanka', 'Iraq'),
#  ('India', 'Iraq'),
#  ('Egypt', 'Iraq'),
#  ('Iran', 'Iraq'),
#  ('Afghanistan', 'Iraq'),
#  ('Korea, South', 'Kuwait'),
#  ('Malaysia', 'Kuwait'),
#  ('Cambodia', 'Kuwait'),
#  ('United Arab Emirates', 'Kuwait'),
#  ('Philippines', 'Kuwait'),
#  ('United Kingdom', 'Kuwait'),
#  ('Italy', 'Kuwait'),
#  ('Egypt', 'Kuwait'),
#  ('Iran', 'Kuwait'),
#  ('US', 'Bahrain'),
#  ('Taiwan*', 'Bahrain'),
#  ('Nepal', 'Bahrain'),
#  ('Finland', 'Bahrain'),
#  ('Egypt', 'Bahrain'),
#  ('Kuwait', 'Bahrain'),
#  ('Vietnam', 'Oman'),
#  ('Cambodia', 'Oman'),
#  ('Lebanon', 'Oman'),
#  ('Israel', 'Oman'),
#  ('Bahrain', 'Oman'),
#  ('US', 'Algeria'),
#  ('Vietnam', 'Algeria'),
#  ('Australia', 'Algeria'),
#  ('Germany', 'Algeria'),
#  ('Egypt', 'Algeria'),
#  ('Kuwait', 'Algeria'),
#  ('US', 'Croatia'),
#  ('Taiwan*', 'Croatia'),
#  ('Korea, South', 'Croatia'),
#  ('Singapore', 'Croatia'),
#  ('France', 'Croatia'),
#  ('Sri Lanka', 'Croatia'),
#  ('Israel', 'Croatia'),
#  ('Afghanistan', 'Croatia'),
#  ('China', 'Austria'),
#  ('Thailand', 'Austria'),
#  ('Korea, South', 'Austria'),
#  ('Singapore', 'Austria'),
#  ('France', 'Austria'),
#  ('Australia', 'Austria'),
#  ('Japan', 'Austria'),
#  ('Cambodia', 'Austria'),
#  ('Germany', 'Austria'),
#  ('Finland', 'Austria'),
#  ('Belgium', 'Austria'),
#  ('Lebanon', 'Austria'),
#  ('Israel', 'Austria'),
#  ('Oman', 'Austria'),
#  ('Croatia', 'Austria'),
#  ('Thailand', 'Switzerland'),
#  ('Korea, South', 'Switzerland'),
#  ('Singapore', 'Switzerland'),
#  ('France', 'Switzerland'),
#  ('Australia', 'Switzerland'),
#  ('Japan', 'Switzerland'),
#  ('Cambodia', 'Switzerland'),
#  ('Italy', 'Switzerland'),
#  ('Belgium', 'Switzerland'),
#  ('US', 'Pakistan'),
#  ('Philippines', 'Pakistan'),
#  ('Russia', 'Pakistan'),
#  ('Egypt', 'Pakistan'),
#  ('Iran', 'Pakistan'),
#  ('Kuwait', 'Pakistan'),
#  ('Bahrain', 'Pakistan'),
#  ('Vietnam', 'Georgia'),
#  ('Canada', 'Georgia'),
#  ('Japan', 'Georgia'),
#  ('US', 'Norway'),
#  ('Singapore', 'Norway'),
#  ('Spain', 'Norway'),
#  ('Austria', 'Norway'),
#  ('Switzerland', 'Norway'),
#  ('China', 'Greece'),
#  ('Nepal', 'Greece'),
#  ('Germany', 'Greece'),
#  ('Lebanon', 'Greece'),
#  ('Korea, South', 'North Macedonia'),
#  ('Russia', 'North Macedonia'),
#  ('Iraq', 'North Macedonia'),
#  ('Oman', 'North Macedonia'),
#  ('Pakistan', 'North Macedonia'),
#  ('Singapore', 'Romania'),
#  ('India', 'Romania'),
#  ('Belgium', 'Romania'),
#  ('Chile', 'Romania'),
#  ('Vietnam', 'Brazil'),
#  ('Taiwan*', 'Brazil'),
#  ('Nepal', 'Brazil'),
#  ('Cambodia', 'Brazil'),
#  ('Sri Lanka', 'Brazil'),
#  ('Egypt', 'Brazil'),
#  ('Israel', 'Brazil'),
#  ('Chile', 'Brazil'),
#  ('Kuwait', 'Brazil'),
#  ('Oman', 'Brazil'),
#  ('Romania', 'Brazil'),
#  ('China', 'Estonia'),
#  ('Australia', 'Estonia'),
#  ('Germany', 'Estonia'),
#  ('Afghanistan', 'Estonia'),
#  ('China', 'Denmark'),
#  ('Finland', 'Denmark'),
#  ('Greece', 'Denmark'),
#  ('Korea, South', 'Netherlands'),
#  ('Singapore', 'Netherlands'),
#  ('Australia', 'Netherlands'),
#  ('United Arab Emirates', 'Netherlands'),
#  ('Spain', 'Netherlands'),
#  ('Belgium', 'Netherlands'),
#  ('Lebanon', 'Netherlands'),
#  ('Oman', 'Netherlands'),
#  ('Korea, South', 'New Zealand'),
#  ('Nepal', 'New Zealand'),
#  ('Singapore', 'New Zealand'),
#  ('France', 'New Zealand'),
#  ('Australia', 'New Zealand'),
#  ('Japan', 'New Zealand'),
#  ('Cambodia', 'New Zealand'),
#  ('Germany', 'New Zealand'),
#  ('Iran', 'New Zealand'),
#  ('Israel', 'New Zealand'),
#  ('Croatia', 'New Zealand'),
#  ('Switzerland', 'New Zealand'),
#  ('Norway', 'New Zealand'),
#  ('Greece', 'New Zealand'),
#  ('Denmark', 'New Zealand'),
#  ('US', 'Nigeria'),
#  ('Korea, South', 'Nigeria'),
#  ('Nepal', 'Nigeria'),
#  ('United Arab Emirates', 'Nigeria'),
#  ('Russia', 'Nigeria'),
#  ('Egypt', 'Nigeria'),
#  ('Netherlands', 'Nigeria'),
#  ('China', 'Iceland'),
#  ('Vietnam', 'Iceland'),
#  ('Thailand', 'Iceland'),
#  ('Korea, South', 'Iceland'),
#  ('France', 'Iceland'),
#  ('Belgium', 'Iceland'),
#  ('Afghanistan', 'Iceland'),
#  ('Croatia', 'Iceland'),
#  ('Switzerland', 'Iceland'),
#  ('Georgia', 'Iceland'),
#  ('Norway', 'Iceland'),
#  ('Netherlands', 'Iceland'),
#  ('New Zealand', 'Iceland'),
#  ('US', 'Belarus'),
#  ('Korea, South', 'Belarus'),
#  ('Japan', 'Belarus'),
#  ('United Arab Emirates', 'Belarus'),
#  ('United Kingdom', 'Belarus'),
#  ('Russia', 'Belarus'),
#  ('Spain', 'Belarus'),
#  ('Afghanistan', 'Belarus'),
#  ('Georgia', 'Belarus'),
#  ('Canada', 'Mexico'),
#  ('Cambodia', 'Mexico'),
#  ('Spain', 'Mexico'),
#  ('Algeria', 'Mexico'),
#  ('North Macedonia', 'Mexico'),
#  ('Brazil', 'Mexico'),
#  ('Greece', 'Monaco'),
#  ('Iceland', 'Monaco'),
#  ('Nepal', 'Luxembourg'),
#  ('France', 'Luxembourg'),
#  ('Japan', 'Luxembourg'),
#  ('Sri Lanka', 'Luxembourg'),
#  ('United Arab Emirates', 'Luxembourg'),
#  ('Iran', 'Luxembourg'),
#  ('Israel', 'Luxembourg'),
#  ('Croatia', 'Luxembourg'),
#  ('Austria', 'Luxembourg'),
#  ('Switzerland', 'Luxembourg'),
#  ('Greece', 'Luxembourg'),
#  ('Estonia', 'Luxembourg'),
#  ('Denmark', 'Luxembourg'),
#  ('China', 'Ireland'),
#  ('Vietnam', 'Ireland'),
#  ('France', 'Ireland'),
#  ('Australia', 'Ireland'),
#  ('Japan', 'Ireland'),
#  ('United Kingdom', 'Ireland'),
#  ('Russia', 'Ireland'),
#  ('Belgium', 'Ireland'),
#  ('Iran', 'Ireland'),
#  ('Lebanon', 'Ireland'),
#  ('Israel', 'Ireland'),
#  ('Taiwan*', 'Qatar'),
#  ('Korea, South', 'Qatar'),
#  ('Singapore', 'Qatar'),
#  ('Sri Lanka', 'Qatar'),
#  ('United Arab Emirates', 'Qatar'),
#  ('Chile', 'Qatar'),
#  ('Afghanistan', 'Qatar'),
#  ('Kuwait', 'Qatar'),
#  ('Algeria', 'Qatar'),
#  ('Croatia', 'Qatar'),
#  ('Belarus', 'Qatar'),
#  ('US', 'Azerbaijan'),
#  ('Nepal', 'Azerbaijan'),
#  ('Canada', 'Azerbaijan'),
#  ('Singapore', 'Azerbaijan'),
#  ('Cambodia', 'Azerbaijan'),
#  ('United Arab Emirates', 'Azerbaijan'),
#  ('Philippines', 'Azerbaijan'),
#  ('Egypt', 'Azerbaijan'),
#  ('Lebanon', 'Azerbaijan'),
#  ('Afghanistan', 'Azerbaijan'),
#  ('Oman', 'Azerbaijan'),
#  ('Georgia', 'Azerbaijan'),
#  ('Monaco', 'Azerbaijan'),
#  ('Vietnam', 'Czechia'),
#  ('Sri Lanka', 'Czechia'),
#  ('Iran', 'Czechia'),
#  ('Oman', 'Czechia'),
#  ('Brazil', 'Czechia'),
#  ('Denmark', 'Czechia'),
#  ('Belarus', 'Czechia'),
#  ('Luxembourg', 'Czechia'),
#  ('Nepal', 'Dominican Republic'),
#  ('Japan', 'Dominican Republic'),
#  ('Cambodia', 'Dominican Republic'),
#  ('Sri Lanka', 'Dominican Republic'),
#  ('Finland', 'Dominican Republic'),
#  ('United Arab Emirates', 'Dominican Republic'),
#  ('Israel', 'Dominican Republic'),
#  ('Algeria', 'Dominican Republic'),
#  ('Croatia', 'Dominican Republic'),
#  ('Greece', 'Dominican Republic'),
#  ('Romania', 'Dominican Republic'),
#  ('Estonia', 'Dominican Republic'),
#  ('Monaco', 'Dominican Republic'),
#  ('Ireland', 'Dominican Republic'),
#  ('Azerbaijan', 'Dominican Republic'),
#  ('Czechia', 'Dominican Republic'),
#  ('Egypt', 'Armenia'),
#  ('Georgia', 'Armenia'),
#  ('Dominican Republic', 'Armenia'),
#  ('US', 'Ecuador'),
#  ('Spain', 'Ecuador'),
#  ('Ireland', 'Ecuador'),
#  ('Taiwan*', 'Latvia'),
#  ('Nepal', 'Latvia'),
#  ('Germany', 'Latvia'),
#  ('Italy', 'Senegal'),
#  ('Lebanon', 'Senegal'),
#  ('Ireland', 'Senegal'),
#  ('Nepal', 'Indonesia'),
#  ('Japan', 'Indonesia'),
#  ('United Arab Emirates', 'Indonesia'),
#  ('Iran', 'Indonesia'),
#  ('Iraq', 'Indonesia'),
#  ('Pakistan', 'Indonesia'),
#  ('Brazil', 'Indonesia'),
#  ('Denmark', 'Indonesia'),
#  ('Senegal', 'Indonesia'),
#  ('Korea, South', 'Morocco'),
#  ('Nepal', 'Morocco'),
#  ('Singapore', 'Morocco'),
#  ('Cambodia', 'Morocco'),
#  ('Lebanon', 'Morocco'),
#  ('Afghanistan', 'Morocco'),
#  ('Oman', 'Morocco'),
#  ('Brazil', 'Morocco'),
#  ('Dominican Republic', 'Morocco'),
#  ('Vietnam', 'Portugal'),
#  ('Taiwan*', 'Portugal'),
#  ('Korea, South', 'Portugal'),
#  ('Malaysia', 'Portugal'),
#  ('Singapore', 'Portugal'),
#  ('France', 'Portugal'),
#  ('Sri Lanka', 'Portugal'),
#  ('Germany', 'Portugal'),
#  ('Georgia', 'Portugal'),
#  ('North Macedonia', 'Portugal'),
#  ('US', 'Saudi Arabia'),
#  ('Malaysia', 'Saudi Arabia'),
#  ('Singapore', 'Saudi Arabia'),
#  ('Japan', 'Saudi Arabia'),
#  ('Sri Lanka', 'Saudi Arabia'),
#  ('United Arab Emirates', 'Saudi Arabia'),
#  ('Croatia', 'Saudi Arabia'),
#  ('Pakistan', 'Saudi Arabia'),
#  ('Nigeria', 'Saudi Arabia'),
#  ('Qatar', 'Saudi Arabia'),
#  ('Armenia', 'Saudi Arabia'),
#  ('Ecuador', 'Saudi Arabia'),
#  ('US', 'Jordan'),
#  ('Korea, South', 'Jordan'),
#  ('Nepal', 'Ukraine'),
#  ('Singapore', 'Ukraine'),
#  ('Japan', 'Ukraine'),
#  ('Cambodia', 'Ukraine'),
#  ('Iraq', 'Ukraine'),
#  ('Oman', 'Ukraine'),
#  ('Croatia', 'Ukraine'),
#  ('Georgia', 'Ukraine'),
#  ('Luxembourg', 'Ukraine'),
#  ('Ireland', 'Ukraine'),
#  ('Senegal', 'Ukraine'),
#  ('Korea, South', 'Argentina'),
#  ('Nepal', 'Argentina'),
#  ('Cambodia', 'Argentina'),
#  ('India', 'Argentina'),
#  ('Spain', 'Argentina'),
#  ('Iran', 'Argentina'),
#  ('Chile', 'Argentina'),
#  ('Oman', 'Argentina'),
#  ('North Macedonia', 'Argentina'),
#  ('Brazil', 'Argentina'),
#  ('Denmark', 'Argentina'),
#  ('Ecuador', 'Argentina'),
#  ('China', 'Tunisia'),
#  ('Korea, South', 'Tunisia'),
#  ('Cambodia', 'Tunisia'),
#  ('Georgia', 'Tunisia'),
#  ('Greece', 'Tunisia'),
#  ('Ireland', 'Tunisia'),
#  ('Belgium', 'Liechtenstein'),
#  ('Switzerland', 'Liechtenstein'),
#  ('Ireland', 'Hungary'),
#  ('Azerbaijan', 'Hungary'),
#  ('Ecuador', 'Hungary'),
#  ('China', 'Poland'),
#  ('Japan', 'Poland'),
#  ('Chile', 'Poland'),
#  ('Azerbaijan', 'Poland'),
#  ('Morocco', 'Poland'),
#  ('Liechtenstein', 'Poland'),
#  ('France', 'Slovenia'),
#  ('Russia', 'Slovenia'),
#  ('Lebanon', 'Slovenia'),
#  ('Croatia', 'Slovenia'),
#  ('Austria', 'Slovenia'),
#  ('Georgia', 'Slovenia'),
#  ('US', 'West Bank and Gaza'),
#  ('Canada', 'West Bank and Gaza'),
#  ('Croatia', 'West Bank and Gaza'),
#  ('Portugal', 'West Bank and Gaza'),
#  ('Vietnam', 'Bosnia and Herzegovina'),
#  ('Thailand', 'Bosnia and Herzegovina'),
#  ('Israel', 'Bosnia and Herzegovina'),
#  ('Chile', 'South Africa'),
#  ('Oman', 'South Africa'),
#  ('Georgia', 'South Africa'),
#  ('Luxembourg', 'South Africa'),
#  ('Dominican Republic', 'South Africa'),
#  ('Jordan', 'South Africa'),
#  ('Vietnam', 'Togo'),
#  ('Egypt', 'Togo'),
#  ('Kuwait', 'Togo'),
#  ('US', 'Slovakia'),
#  ('Korea, South', 'Slovakia'),
#  ('Singapore', 'Slovakia'),
#  ('Austria', 'Slovakia'),
#  ('Netherlands', 'Slovakia'),
#  ('Hungary', 'Slovakia'),
#  ('Slovenia', 'Slovakia'),
#  ('US', 'Serbia'),
#  ('Kuwait', 'Serbia'),
#  ('Greece', 'Serbia'),
#  ('Ireland', 'Serbia'),
#  ('Nepal', 'Costa Rica'),
#  ('India', 'Costa Rica'),
#  ('Oman', 'Costa Rica'),
#  ('Croatia', 'Costa Rica'),
#  ('India', 'Colombia'),
#  ('Croatia', 'Colombia'),
#  ('Bosnia and Herzegovina', 'Colombia'),
#  ('Vietnam', 'Peru'),
#  ('Italy', 'Peru'),
#  ('South Africa', 'Peru'),
#  ('Vietnam', 'Malta'),
#  ('Singapore', 'Malta'),
#  ('Iran', 'Malta'),
#  ('Denmark', 'Malta'),
#  ('Poland', 'Malta'),
#  ('US', 'Bulgaria'),
#  ('Vietnam', 'Bulgaria'),
#  ('Nepal', 'Bulgaria'),
#  ('Cambodia', 'Bulgaria'),
#  ('Iran', 'Bulgaria'),
#  ('Lebanon', 'Bulgaria'),
#  ('Oman', 'Bulgaria'),
#  ('Brazil', 'Bulgaria'),
#  ('Denmark', 'Bulgaria'),
#  ('Luxembourg', 'Bulgaria'),
#  ('Ecuador', 'Bulgaria'),
#  ('Indonesia', 'Bulgaria'),
#  ('Saudi Arabia', 'Bulgaria'),
#  ('Tunisia', 'Bulgaria'),
#  ('Bosnia and Herzegovina', 'Bulgaria'),
#  ('Slovakia', 'Bulgaria'),
#  ('Peru', 'Bulgaria'),
#  ('Malta', 'Bulgaria'),
#  ('Nepal', 'Paraguay'),
#  ('Russia', 'Paraguay'),
#  ('Lebanon', 'Paraguay'),
#  ('Oman', 'Paraguay'),
#  ('Croatia', 'Paraguay'),
#  ('Czechia', 'Paraguay'),
#  ('Nepal', 'Bangladesh'),
#  ('Finland', 'Bangladesh'),
#  ('Afghanistan', 'Bangladesh'),
#  ('Bahrain', 'Bangladesh'),
#  ('Nigeria', 'Bangladesh'),
#  ('Czechia', 'Bangladesh'),
#  ('Jordan', 'Bangladesh'),
#  ('Peru', 'Bangladesh'),
#  ('Singapore', 'Maldives'),
#  ('Australia', 'Maldives'),
#  ('Philippines', 'Maldives'),
#  ('Oman', 'Maldives'),
#  ('Slovakia', 'Maldives'),
#  ('Peru', 'Maldives'),
#  ('Pakistan', 'Moldova'),
#  ('Brazil', 'Moldova'),
#  ('Ireland', 'Moldova'),
#  ('Poland', 'Moldova'),
#  ('Sri Lanka', 'Albania'),
#  ('United Arab Emirates', 'Albania'),
#  ('Afghanistan', 'Albania'),
#  ('Greece', 'Albania'),
#  ('Saudi Arabia', 'Albania'),
#  ('Jordan', 'Albania'),
#  ('Argentina', 'Albania'),
#  ('Tunisia', 'Albania'),
#  ('Serbia', 'Albania'),
#  ('Peru', 'Albania'),
#  ('Bulgaria', 'Albania'),
#  ('Morocco', 'Mongolia'),
#  ('Togo', 'Mongolia'),
#  ('Iran', 'Cyprus'),
#  ('Denmark', 'Cyprus'),
#  ('Netherlands', 'Cyprus'),
#  ('Taiwan*', 'Panama'),
#  ('Chile', 'Panama'),
#  ('Iraq', 'Panama'),
#  ('Kuwait', 'Panama'),
#  ('Jordan', 'Panama'),
#  ('Poland', 'Panama'),
#  ('South Africa', 'Panama'),
#  ('Malta', 'Panama'),
#  ('Bulgaria', 'Panama'),
#  ('Maldives', 'Panama'),
#  ('Albania', 'Panama'),
#  ('Sri Lanka', 'Congo (Kinshasa)'),
#  ('Egypt', 'Congo (Kinshasa)'),
#  ('Togo', 'Congo (Kinshasa)'),
#  ('Serbia', 'Congo (Kinshasa)'),
#  ('Moldova', 'Congo (Kinshasa)'),
#  ('Singapore', 'Jamaica'),
#  ('Kuwait', 'Jamaica'),
#  ('Georgia', 'Jamaica'),
#  ('Ecuador', 'Jamaica'),
#  ('Morocco', 'Jamaica'),
#  ('Singapore', "Cote d'Ivoire"),
#  ('Sri Lanka', "Cote d'Ivoire"),
#  ('United Arab Emirates', "Cote d'Ivoire"),
#  ('Czechia', "Cote d'Ivoire"),
#  ('Ecuador', "Cote d'Ivoire"),
#  ('Senegal', "Cote d'Ivoire"),
#  ('Portugal', "Cote d'Ivoire"),
#  ('Saudi Arabia', "Cote d'Ivoire"),
#  ('Jordan', "Cote d'Ivoire"),
#  ('South Africa', "Cote d'Ivoire"),
#  ('Peru', "Cote d'Ivoire"),
#  ('Malta', "Cote d'Ivoire"),
#  ('Paraguay', "Cote d'Ivoire"),
#  ('Moldova', "Cote d'Ivoire"),
#  ('Mongolia', "Cote d'Ivoire"),
#  ('Sri Lanka', 'Honduras'),
#  ('Pakistan', 'Honduras'),
#  ('Georgia', 'Honduras'),
#  ('Luxembourg', 'Honduras'),
#  ('Saudi Arabia', 'Honduras'),
#  ('Jordan', 'Honduras'),
#  ('West Bank and Gaza', 'Honduras'),
#  ('Malta', 'Honduras'),
#  ('Panama', 'Honduras'),
#  ('Congo (Kinshasa)', 'Honduras'),
#  ('Austria', 'Turkey'),
#  ('Denmark', 'Turkey'),
#  ('Ireland', 'Turkey'),
#  ('Portugal', 'Turkey'),
#  ('Liechtenstein', 'Turkey'),
#  ('Mexico', 'Bolivia'),
#  ('Qatar', 'Bolivia'),
#  ('Peru', 'Bolivia'),
#  ('Georgia', 'Cuba'),
#  ('Morocco', 'Cuba'),
#  ('Hungary', 'Cuba'),
#  ('South Africa', 'Cuba'),
#  ('Philippines', 'Guyana'),
#  ('France', 'Uruguay'),
#  ('Pakistan', 'Uruguay'),
#  ('Luxembourg', 'Uruguay'),
#  ('China', 'Kenya'),
#  ('Korea, South', 'Kenya'),
#  ('Sri Lanka', 'Kenya'),
#  ('India', 'Kenya'),
#  ('Lebanon', 'Kenya'),
#  ('Afghanistan', 'Kenya'),
#  ('Kuwait', 'Kenya'),
#  ('Georgia', 'Kenya'),
#  ('Luxembourg', 'Kenya'),
#  ('Jordan', 'Kenya'),
#  ('Bosnia and Herzegovina', 'Kenya'),
#  ('South Africa', 'Kenya'),
#  ('Togo', 'Kenya'),
#  ('Panama', 'Kenya'),
#  ('India', 'Ethiopia'),
#  ('Qatar', 'Ethiopia'),
#  ('Tunisia', 'Ethiopia'),
#  ('West Bank and Gaza', 'Kazakhstan'),
#  ('Vietnam', 'Rwanda'),
#  ('Korea, South', 'Rwanda'),
#  ('Philippines', 'Rwanda'),
#  ('Afghanistan', 'Rwanda'),
#  ('Monaco', 'Rwanda'),
#  ('Slovakia', 'Rwanda'),
#  ('Panama', 'Rwanda'),
#  ('Ethiopia', 'Rwanda'),
#  ('China', 'Trinidad and Tobago'),
#  ('Korea, South', 'Trinidad and Tobago'),
#  ('Lebanon', 'Trinidad and Tobago'),
#  ('Croatia', 'Trinidad and Tobago'),
#  ('Estonia', 'Trinidad and Tobago'),
#  ('South Africa', 'Trinidad and Tobago'),
#  ('Vietnam', 'Namibia'),
#  ('Korea, South', 'Namibia'),
#  ('Philippines', 'Namibia'),
#  ('Lebanon', 'Namibia'),
#  ('Croatia', 'Namibia'),
#  ('Monaco', 'Namibia'),
#  ('Peru', 'Namibia'),
#  ('Mongolia', 'Namibia'),
#  ('Congo (Kinshasa)', 'Namibia'),
#  ('Honduras', 'Namibia'),
#  ('United Arab Emirates', 'Mauritania'),
#  ('Egypt', 'Mauritania'),
#  ('Moldova', 'Mauritania'),
#  ('Honduras', 'Mauritania'),
#  ('Kenya', 'Mauritania'),
#  ('India', 'Venezuela'),
#  ('Cuba', 'Venezuela'),
#  ('Trinidad and Tobago', 'Venezuela'),
#  ('Vietnam', 'Eswatini'),
#  ('Colombia', 'Eswatini'),
#  ('India', 'Suriname'),
#  ('Cuba', 'Suriname'),
#  ('Qatar', 'Kosovo'),
#  ('Serbia', 'Kosovo'),
#  ('Maldives', 'Kosovo'),
#  ("Cote d'Ivoire", 'Kosovo'),
#  ('Kenya', 'Kosovo'),
#  ('Maldives', 'Guatemala'),
#  ('Bolivia', 'Guatemala'),
#  ('Mauritania', 'Guatemala'),
#  ('Vietnam', 'Uzbekistan'),
#  ('Cambodia', 'Uzbekistan'),
#  ('Sri Lanka', 'Uzbekistan'),
#  ('Israel', 'Uzbekistan'),
#  ('Georgia', 'Uzbekistan'),
#  ('Brazil', 'Uzbekistan'),
#  ('Latvia', 'Uzbekistan'),
#  ('Serbia', 'Uzbekistan'),
#  ('Colombia', 'Uzbekistan'),
#  ("Cote d'Ivoire", 'Uzbekistan'),
#  ('Uruguay', 'Uzbekistan'),
#  ('Kosovo', 'Uzbekistan'),
#  ('Japan', 'Bahamas'),
#  ('Lebanon', 'Bahamas'),
#  ('Oman', 'Bahamas'),
#  ('Ethiopia', 'Bahamas'),
#  ('Cyprus', 'Barbados'),
#  ('Turkey', 'Barbados'),
#  ('Nepal', 'Montenegro'),
#  ('Afghanistan', 'Montenegro'),
#  ('Guatemala', 'Montenegro'),
#  ('Korea, South', 'Zambia'),
#  ('Cambodia', 'Zambia'),
#  ('Sri Lanka', 'Zambia'),
#  ('Croatia', 'Zambia'),
#  ('Romania', 'Zambia'),
#  ('Denmark', 'Zambia'),
#  ('Togo', 'Zambia'),
#  ('Malta', 'Zambia'),
#  ("Cote d'Ivoire", 'Zambia'),
#  ('Guyana', 'Zambia'),
#  ('Montenegro', 'Zambia'),
#  ('Iran', 'Djibouti'),
#  ('North Macedonia', 'Djibouti'),
#  ('Denmark', 'Djibouti'),
#  ('Qatar', 'Djibouti'),
#  ('Saudi Arabia', 'Djibouti'),
#  ('Togo', 'Djibouti'),
#  ('Slovakia', 'Djibouti'),
#  ('Serbia', 'Djibouti'),
#  ('Uruguay', 'Djibouti'),
#  ('Croatia', 'Kyrgyzstan'),
#  ('Brazil', 'Kyrgyzstan'),
#  ('Guatemala', 'Kyrgyzstan'),
#  ('Montenegro', 'Kyrgyzstan'),
#  ('China', 'Lithuania'),
#  ('France', 'Lithuania'),
#  ('Netherlands', 'Lithuania'),
#  ('Rwanda', 'Angola'),
#  ('Uzbekistan', 'Angola'),
#  ('Taiwan*', 'Niger'),
#  ('Singapore', 'Niger'),
#  ('France', 'Niger'),
#  ('North Macedonia', 'Niger'),
#  ('Malta', 'Niger'),
#  ('Jamaica', 'Niger'),
#  ('Turkey', 'Niger'),
#  ('Monaco', 'Zimbabwe'),
#  ('Uruguay', 'Zimbabwe'),
#  ('Kenya', 'Zimbabwe'),
#  ('Barbados', 'Zimbabwe'),
#  ('Egypt', 'Haiti'),
#  ('Kazakhstan', 'Haiti'),
#  ('Trinidad and Tobago', 'Haiti'),
#  ('Djibouti', 'Haiti'),
#  ('Singapore', 'Cabo Verde'),
#  ('Sri Lanka', 'Cabo Verde'),
#  ('Paraguay', 'Cabo Verde'),
#  ('Jamaica', 'Cabo Verde'),
#  ('Bolivia', 'Cabo Verde'),
#  ('Kazakhstan', 'Cabo Verde'),
#  ('Bahamas', 'Cabo Verde'),
#  ('Korea, South', 'Uganda'),
#  ('Peru', 'Uganda'),
#  ('Mongolia', 'Uganda'),
#  ('Cuba', 'Uganda'),
#  ('Haiti', 'Uganda'),
#  ('Lebanon', 'Syria'),
#  ('Morocco', 'Syria'),
#  ('Venezuela', 'Mozambique'),
#  ('Paraguay', 'Belize'),
#  ('Trinidad and Tobago', 'Belize'),
#  ('New Zealand', 'Laos'),
#  ('Spain', 'Libya'),
#  ('Lebanon', 'Libya'),
#  ('Georgia', 'Libya'),
#  ('Monaco', 'Libya'),
#  ('Dominican Republic', 'Libya'),
#  ('Morocco', 'Libya'),
#  ('Bosnia and Herzegovina', 'Libya'),
#  ('Venezuela', 'Libya'),
#  ('Bahamas', 'Libya'),
#  ('Barbados', 'Libya'),
#  ('Qatar', 'Mali'),
#  ('Turkey', 'Burma'),
#  ('Dominican Republic', 'Malawi'),
#  ('South Africa', 'Malawi'),
#  ('Bahrain', 'Yemen'),
#  ('Pakistan', 'Yemen')]

# %%
len(DAGresult[0])
# Out:
# 140

# %%
len(DAGresult[1])
# Out:
# 814

# %%
cont = pd.read_csv("continent.csv")
countries = list(set([item for sublist in DAGresult[1] for item in sublist]))
cont = cont[["Country Name", "continent"]]
merged_df = pd.merge(pd.DataFrame({"Country Name": countries}), cont, on="Country Name")

# %%
america_df = merged_df[merged_df["continent"] == "America"]
america_countries = america_df["Country Name"].tolist()
filtered_list_america = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if c1 in america_countries and c2 in america_countries]
filtered_list_america
# Out:
# [('US', 'Canada'),
#  ('US', 'Chile'),
#  ('Chile', 'Brazil'),
#  ('Canada', 'Mexico'),
#  ('Brazil', 'Mexico'),
#  ('US', 'Ecuador'),
#  ('Chile', 'Argentina'),
#  ('Brazil', 'Argentina'),
#  ('Ecuador', 'Argentina'),
#  ('Chile', 'Panama'),
#  ('Ecuador', 'Jamaica'),
#  ('Panama', 'Honduras'),
#  ('Mexico', 'Bolivia'),
#  ('Peru', 'Bolivia'),
#  ('Cuba', 'Venezuela'),
#  ('Trinidad and Tobago', 'Venezuela'),
#  ('Cuba', 'Suriname'),
#  ('Bolivia', 'Guatemala'),
#  ('Trinidad and Tobago', 'Haiti'),
#  ('Paraguay', 'Belize'),
#  ('Trinidad and Tobago', 'Belize')]

# %%
filtered_list = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if merged_df.loc[merged_df["Country Name"] == c1, "continent"].iloc[0] ==
                 merged_df.loc[merged_df["Country Name"] == c2, "continent"].iloc[0]]

# %%
len(filtered_list)
# Out:
# 252

# %%
america_df = merged_df[merged_df["continent"] == "America"]
america_countries = america_df["Country Name"].tolist()
filtered_list_america = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if c1 in america_countries and c2 in america_countries]
len(filtered_list_america)
# Out:
# 21

# %%
asia_df = merged_df[merged_df["continent"] == "Asia"]
asia_countries = asia_df["Country Name"].tolist()
filtered_list_asia = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if c1 in asia_countries and c2 in asia_countries]
len(filtered_list_asia)
# Out:
# 106

# %%
euro_df = merged_df[merged_df["continent"] == "Europe"]
euro_countries = euro_df["Country Name"].tolist()
filtered_list_euro = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if c1 in euro_countries and c2 in euro_countries]
len(filtered_list_euro)
# Out:
# 103

# %%
africa_df = merged_df[merged_df["continent"] == "Africa"]
africa_countries = africa_df["Country Name"].tolist()
filtered_list_africa = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if c1 in africa_countries and c2 in africa_countries]
len(filtered_list_africa)
# Out:
# 21

# %%
australia_df = merged_df[merged_df["continent"] == "Australia"]
australia_countries = australia_df["Country Name"].tolist()
filtered_list_australia = [(c1, c2) for (c1, c2) in DAGresult[1]
                 if c1 in australia_countries and c2 in australia_countries]
len(filtered_list_australia)
# Out:
# 1

# %%
filtered_list_australia
# Out:
# [('Australia', 'New Zealand')]

# %%
america = pd.DataFrame(filtered_list_america)
america.to_csv("america.csv")

# %%
africa = pd.DataFrame(filtered_list_africa)
africa.to_csv("africa.csv")

# %%
asia = pd.DataFrame(filtered_list_asia)
asia.to_csv("asia.csv")

# %%
euro = pd.DataFrame(filtered_list_euro)
euro.to_csv("euro.csv")
